# %%
from matplotlib.pyplot import *
import matplotlib.pyplot as plt

x = [50000,100000,200000,300000,400000, 500000,600000,700000]
y = [ 1.6 , 1.7 , 1.4, 1.24, 1.46, 1.63, 1.4, 1.4]
plt.ylabel('Speedup')
plt.xlabel('size of dataset')

plot(x,y,'-r')
